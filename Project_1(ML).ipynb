# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

url = "https://storage.googleapis.com/kagglesdsdata/datasets/4458/8204/winequality-red.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240812%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240812T154955Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
response = requests.get(url)

# Save the content to a file
with open("winequality-red.csv", "wb") as file:
    file.write(response.content)

# %%
data=pd.read_csv("Wine.csv")
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.lineplot(y="pH",x="quality",data=data,color="green")
plt.title("pH VS Quality",fontsize=15)
plt.xlabel("Quality",color="blue")
plt.ylabel("pH Level",color="blue")
# Out:
# Text(0, 0.5, 'pH Level')

# %% [markdown]
# # As we can see the Quality and pH level of Wine is correlated.
# # If the pH decreases then the Quality of wine increases

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(y="alcohol",x="quality",data=data,color="green")
plt.title("alcohol VS Quality",fontsize=15)
plt.xlabel("Quality",color="blue")
plt.ylabel("Alcohol",color="blue")
# Out:
# Text(0, 0.5, 'Alcohol')

# %% [markdown]
# # The quality of Wines increases as we increase the alcohol level of wine

# %%
sns.lineplot(y="volatile acidity",x="quality",data=data,color="green")
plt.title("volatile Acidity VS Quality",fontsize=15)
plt.xlabel("Quality",color="blue")
plt.ylabel("volatile acidity",color="blue")
# Out:
# Text(0, 0.5, 'volatile acidity')

# %% [markdown]
# # The quality of Wines increases as we decrease the Acidity level of wine

# %%
sns.lineplot(y="citric acid",x="quality",data=data,color="green")
plt.title("Citric Acid VS Quality",fontsize=15)
plt.xlabel("Quality",color="blue")
plt.ylabel("Citric Acid",color="blue")
# Out:
# Text(0, 0.5, 'Citric Acid')

# %% [markdown]
# # The quality of Wines increases as we increase the Citric Acid level of wine

# %%
sns.lineplot(y="sulphates",x="quality",data=data,color="green")
plt.title("Sulphates VS Quality",fontsize=15)
plt.xlabel("Quality",color="blue")
plt.ylabel("Sulphates",color="blue")
# Out:
# Text(0, 0.5, 'Sulphates')

# %% [markdown]
# # The quality of Wines increases as we increase the Sulphates of wine

# %%
quality_counts = data['quality'].value_counts().reset_index()
quality_counts.columns = ['quality', 'count']
sns.barplot(x='quality', y='count', data=quality_counts)
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Count of Each Quality Rating')
plt.show()

# %%
for i in range(len(data)):
    if data.iloc[i,11]>=7:
        data.iloc[i,11]='good'
    else:
        data.iloc[i,11]='bad'
# Out:
# /var/folders/km/41xdld515hq8qyv7nx3qq6n80000gn/T/ipykernel_1075/1096815631.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'bad' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.iloc[i,11]='bad'

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()
data['quality']=lb.fit_transform(data['quality'])
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
x=data.drop(["quality"],axis=1)
y=data["quality"]

# %%
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
fr=RandomForestRegressor(n_estimators=40,random_state=0)

# %%
fr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=40, random_state=0)

# %%
y_pred=np.matrix.round(fr.predict(x_test))

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print("Accuracy :",acc*100)
# Out:
# Accuracy : 89.375
